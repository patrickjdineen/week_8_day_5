# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidance to answer the following questions.
#
# 1. Which hosts are the busiest and why?
# 2. How many neighborhood groups are available and which shows up the most?
# 3. Are private rooms the most popular in manhattan?
# 4. Which hosts are the busiest and based on their reviews?
# 5. Which neighorhood group has the highest average price?
# 6. Which neighborhood group has the highest total price?
# 7. Which top 5 hosts have the highest total price?
# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 9. What host has the highest total of prices and where are they located?
# 10. When did Danielle from Queens last receive a review?
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this intire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to similate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('../files/AB_NYC_2019.csv')
air_bnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# How many neighborhood groups are available and which shows up the most?

nabe = air_bnb.groupby('neighbourhood_group').count().sort_values('id', ascending =False)
print("5 groups and Manhattan appears the most")
nabe
# Out:
# 5 groups and Manhattan appears the most
#                         id   name  host_id  host_name  neighbourhood  \
# neighbourhood_group
# Manhattan            21661  21652    21661      21652          21661
# Brooklyn             20104  20098    20104      20095          20104
# Queens                5666   5666     5666       5664           5666
# Bronx                 1091   1090     1091       1090           1091
# Staten Island          373    373      373        373            373
#
#                      latitude  longitude  room_type  price  minimum_nights  \
# neighbourhood_group
# Manhattan               21661      21661      21661  21661           21661
# Brooklyn                20104      20104      20104  20104           20104
# Queens                   5666       5666       5666   5666            5666
# Bronx                    1091       1091       1091   1091            1091
# Staten Island             373        373        373    373             373
#
# ...

# %%
# Are private rooms the most popular in manhattan?

prooms = air_bnb[air_bnb["neighbourhood_group"]=='Manhattan'].groupby('room_type').count().sort_values("id", ascending = False)

print("No, entire home/apt is")
prooms
# Out:
# No, entire home/apt is
#                     id   name  host_id  host_name  neighbourhood_group  \
# room_type
# Entire home/apt  13199  13193    13199      13196                13199
# Private room      7982   7979     7982       7976                 7982
# Shared room        480    480      480        480                  480
#
#                  neighbourhood  latitude  longitude  price  minimum_nights  \
# room_type
# Entire home/apt          13199     13199      13199  13199           13199
# Private room              7982      7982       7982   7982            7982
# Shared room                480       480        480    480             480
#
#                  number_of_reviews  last_review  reviews_per_month  \
# room_type
# Entire home/apt              13199         9967               9967
# Private room                  7982         6309               6309
# Shared room                    480          356                356
#
# ...

# %%
# Which hosts are the busiest and based on their reviews?

busy_host = air_bnb.groupby(["host_name"]).sum('number_of_Reviews').sort_values('number_of_reviews', ascending=False)
print("Michael is the busiest based on number of reviews")
busy_host
# Out:
# Michael is the busiest based on number of reviews
#                          id      host_id     latitude    longitude  price  \
# host_name
# Michael          7430617239  22673153604  16984.89137 -30841.28573  66895
# David            7943862898  28633613354  16414.34392 -29804.53757  65844
# John             5737372154  24525297065  11974.02914 -21743.58993  41892
# Jason            2176696732   6962647849   5700.22907 -10354.60535  19381
# Alex             5496620312  19850092761  11361.10533 -20635.86235  52563
# ...                     ...          ...          ...          ...    ...
# Rabah               3302932      2082345     40.69165    -73.84841    250
# Rabi & Soukaina    34364716      2123674     40.60939    -73.95475     70
# Rachad             13821806      7695239     40.72128    -73.95782    249
# Rachel & Alex      36449345    115528632     40.69171    -73.95418     80
# 현선                 26139678     18497228     40.80485    -73.96534   1200
#
# ...

# %%
#Which neighorhood group has the highest average price?

high_avg = air_bnb.groupby(["neighbourhood_group"]).agg({"price": [np.size, np.mean]})
print("manhattan has the highest price")
high_avg
# Out:
# manhattan has the highest price
#                      price
#                       size        mean
# neighbourhood_group
# Bronx                 1091   87.496792
# Brooklyn             20104  124.383207
# Manhattan            21661  196.875814
# Queens                5666   99.517649
# Staten Island          373  114.812332

# %%
# Which neighbor hood group has the highest total price?
high_total = air_bnb.groupby(["neighbourhood_group"]).sum('price').sort_values('price', ascending = False)
print("Manhattan has the highest total price")
high_total
# Out:
# Manhattan has the highest total price
#                                id        host_id      latitude     longitude  \
# neighbourhood_group
# Manhattan            406683958152  1469279004836  883012.01680 -1.602364e+06
# Brooklyn             367035792483  1140203577483  817931.96821 -1.486715e+06
# Queens               123263814259   544824426112  230784.85597 -4.185631e+05
# Bronx                 24803796188   115220380205   44565.50071 -8.060805e+04
# Staten Island          8055857451    36753031930   15147.61383 -2.764147e+04
#
#                        price  minimum_nights  number_of_reviews  \
# neighbourhood_group
# Manhattan            4264527          185833             454569
# Brooklyn             2500600          121761             486574
# Queens                563867           29358             156950
# Bronx                  95459            4976              28371
# Staten Island          42825            1802              11541
#
# ...

# %%
#Which top 5 hosts have the highest total price?
high_host = air_bnb.groupby(["host_name"]).sum('price').sort_values('price', ascending = False).head(5)
print("Sonder, Blueground, Micheal, David, Alex")
high_host
# Out:
# Sonder, Blueground, Micheal, David, Alex
#                        id      host_id     latitude    longitude  price  \
# host_name
# Sonder (NYC)  10885561678  71782340547  13316.25823 -24198.18856  82795
# Blueground     7210036953  24924786136   9451.60418 -17166.13165  70331
# Michael        7430617239  22673153604  16984.89137 -30841.28573  66895
# David          7943862898  28633613354  16414.34392 -29804.53757  65844
# Alex           5496620312  19850092761  11361.10533 -20635.86235  52563
#
#               minimum_nights  number_of_reviews  reviews_per_month  \
# host_name
# Sonder (NYC)            4353               1281             397.56
# Blueground              7470                 29               6.04
# Michael                 4600              11081             475.82
# David                   3754               8103             508.61
# Alex                    1651               6204             443.44
#
#               calculated_host_listings_count  availability_365
# ...

# %%
# Who currently has no (zero) availability with a review count of 100 or more?
no_avail = air_bnb[(air_bnb.availability_365==0)& (air_bnb.number_of_reviews> 100)].groupby('host_name').sum().sort_values('number_of_reviews', ascending = False)
no_avail
# Out:
#                        id    host_id   latitude  longitude  price  \
# host_name
# Gurpreet  Singh  53343567   91838780  162.78051 -295.30130    209
# Michael          65358392  413675764  203.44757 -369.75171    401
# Deloris          35557158  242782284   81.33135 -147.52700    130
# Brian            23670842    6308882  122.19086 -221.92461    606
# Wanda              166172     792159   40.70283  -73.92131     60
# ...                   ...        ...        ...        ...    ...
# Danielle          4774190   17921968   40.73196  -73.98230    198
# Albert           24267706   21074914   40.68234  -73.91318     49
# Karin              286838    1492339   40.80748  -73.95589     75
# Anna             15462208   26073602   40.79575  -73.94817    145
# Jake              3913635   18834080   40.71672  -73.99184    130
#
#                  minimum_nights  number_of_reviews  reviews_per_month  \
# host_name
# Gurpreet  Singh               4               1061              26.42
# ...

# %%
# What host has the highest total of prices and where are they located?
#

high_cost = air_bnb.groupby(['host_name','neighbourhood_group']).sum("price").sort_values("price", ascending= False)
print("Sonder in Manhattan")
high_cost
# Out:
# Sonder in Manhattan
#                                                 id      host_id     latitude  \
# host_name         neighbourhood_group
# Sonder (NYC)      Manhattan            10885561678  71782340547  13316.25823
# Blueground        Manhattan             7142993903  24709917290   9370.18553
# Michael           Manhattan             3752281462  11887197922   8641.23026
# David             Manhattan             3985751906  14502966311   8234.56426
# Kara              Manhattan             1830785194   4212479709   5501.79014
# ...                                            ...          ...          ...
# Salim             Manhattan               24114389    180661875     40.76844
# Luz               Bronx                   27316669    205820814     40.83454
# Vishanti & Jeremy Brooklyn                21869057     11967922     40.72421
# Qiuchi            Manhattan               20933849     13709292     40.75091
# ...

# %%
# When did Danielle from Queens last receive a review?
danielle = air_bnb[(air_bnb.host_name =="Danielle")& (air_bnb.neighbourhood_group =="Queens")].sort_values("last_review", ascending = False)[["last_review"]]
print("2019-07-08")
danielle
# Out:
# 2019-07-08
#       last_review
# 22469  2019-07-08
# 21517  2019-07-07
# 20403  2019-07-06
# 22068  2019-07-06
# 7086   2019-07-03
# 33861  2019-06-20
# 27021  2018-01-02
# 16349         NaN

# %% [markdown]
# ## Further Questions
#
# 1. Which host has the most listings?

# %%
high_list = air_bnb.groupby(["host_name"]).count().sort_values('id', ascending = False).head(5)
print("Michael has 417 listings")
high_list
# Out:
#                id  name  host_id  neighbourhood_group  neighbourhood  \
# host_name
# Michael       417   417      417                  417            417
# David         403   403      403                  403            403
# Sonder (NYC)  327   327      327                  327            327
# John          294   294      294                  294            294
# Alex          279   279      279                  279            279
#
#               latitude  longitude  room_type  price  minimum_nights  \
# host_name
# Michael            417        417        417    417             417
# David              403        403        403    403             403
# Sonder (NYC)       327        327        327    327             327
# John               294        294        294    294             294
# Alex               279        279        279    279             279
#
#               number_of_reviews  last_review  reviews_per_month  \
# host_name
# ...

# %% [markdown]
# 2. How many listings have completely open availability?

# %%
open_available = air_bnb[(air_bnb.availability_365 ==365)].count()
print("1295 totally oepen items")
open_available
# Out:
# 1295 totally oepen items
# id                                1295
# name                              1294
# host_id                           1295
# host_name                         1295
# neighbourhood_group               1295
# neighbourhood                     1295
# latitude                          1295
# longitude                         1295
# room_type                         1295
# price                             1295
# minimum_nights                    1295
# number_of_reviews                 1295
# last_review                        841
# reviews_per_month                  841
# calculated_host_listings_count    1295
# availability_365                  1295
# dtype: int64

# %% [markdown]
# 3. What room_types have the highest review numbers?

# %%
high_rev = air_bnb.groupby(['room_type']).sum('numbder_of_reviews').sort_values("room_type")
print("entire home/apt")
high_rev
# Out:
# entire home/apt
#                            id        host_id      latitude     longitude  \
# room_type
# Entire home/apt  468495600287  1569156532318  1.034874e+06 -1.879267e+06
# Private room     434663231749  1618079882718  9.093203e+05 -1.650850e+06
# Shared room       26684386497   119044005530  4.724740e+04 -8.577428e+04
#
#                    price  minimum_nights  number_of_reviews  \
# room_type
# Entire home/apt  5381480          216152             580403
# Private room     2004450          120067             538346
# Shared room        81348            7511              19256
#
#                  reviews_per_month  calculated_host_listings_count  \
# room_type
# Entire home/apt           26565.34                          271834
# Private room              25529.62                           72062
# Shared room                1245.08                            5409
#
#                  availability_365
# room_type
# Entire home/apt           2843783
# ...

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --
